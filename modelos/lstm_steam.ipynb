# %%
import tensorflow as tf

model = tf.keras.models.load_model("lstm_steam.h5")

converter = tf.lite.TFLiteConverter.from_keras_model(model)

# 👇 CLAVE PARA QUE FUNCIONE CON LSTM
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
    tf.lite.OpsSet.SELECT_TF_OPS
]

# Evitar que baje TensorListOps
converter._experimental_lower_tensor_list_ops = False

# Puedes agregar optimizations si quieres un modelo más ligero:
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convertir
tflite_model = converter.convert()

with open("lstm_steam.tflite", "wb") as f:
    f.write(tflite_model)

print("✔ Conversión completada con SELECT_TF_OPS")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\DANIELA\AppData\Local\Temp\tmptvl2yo79\assets
# INFO:tensorflow:Assets written to: C:\Users\DANIELA\AppData\Local\Temp\tmptvl2yo79\assets
# Saved artifact at 'C:\Users\DANIELA\AppData\Local\Temp\tmptvl2yo79'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 200), dtype=tf.float32, name='input_layer_5')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1519601934096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1519601933712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1519601932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1519601934672: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
